# %% [markdown]
# # Objective: fine-tuning DETR
#
# -   This notebook can be found on my Github profile: https://github.com/woctezuma/finetune-detr
# -   Official DETR repository: https://github.com/facebookresearch/detr
# -   Discussion about fine-tuning in [a Github issue](https://github.com/facebookresearch/detr/issues/9).
# -   A nice blog post about another approach (Mask R-CNN) and the balloon dataset (which we use in this notebook): [here](https://engineering.matterport.com/splash-of-color-instance-segmentation-with-mask-r-cnn-and-tensorflow-7c761e238b46).

# %%
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())

torch.set_grad_enabled(False)
# Out:
# 2.0.1 False

# %%
import torchvision.transforms as T

# standard PyTorch mean-std input image normalization
transform = T.Compose([
    T.Resize(800),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# for output bounding box post-processing
def box_cxcywh_to_xyxy(x):
    x_c, y_c, w, h = x.unbind(1)
    b = [(x_c - 0.5 * w), (y_c - 0.5 * h),
         (x_c + 0.5 * w), (y_c + 0.5 * h)]
    return torch.stack(b, dim=1)

def rescale_bboxes(out_bbox, size):
    img_w, img_h = size
    b = box_cxcywh_to_xyxy(out_bbox)
    b = b * torch.tensor([img_w, img_h, img_w, img_h], dtype=torch.float32)
    return b

# %%
def filter_bboxes_from_outputs(outputs,
                               threshold=0.7):
  
  # keep only predictions with confidence above threshold
  probas = outputs['pred_logits'].softmax(-1)[0, :, :-1]
  keep = probas.max(-1).values > threshold

  probas_to_keep = probas[keep]

  # convert boxes from [0; 1] to image scales
  bboxes_scaled = rescale_bboxes(outputs['pred_boxes'][0, keep], im.size)
  
  return probas_to_keep, bboxes_scaled

# %%
# COCO classes
CLASSES = [
    'N/A', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A',
    'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse',
    'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack',
    'umbrella', 'N/A', 'N/A', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis',
    'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove',
    'skateboard', 'surfboard', 'tennis racket', 'bottle', 'N/A', 'wine glass',
    'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich',
    'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake',
    'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table', 'N/A',
    'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard',
    'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A',
    'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier',
    'toothbrush'
]

# colors for visualization
COLORS = [[0.000, 0.447, 0.741], [0.850, 0.325, 0.098], [0.929, 0.694, 0.125],
          [0.494, 0.184, 0.556], [0.466, 0.674, 0.188], [0.301, 0.745, 0.933]]

# %%
import matplotlib.pyplot as plt

def plot_results(pil_img, prob=None, boxes=None):
    plt.figure(figsize=(16,10))
    plt.imshow(pil_img)
    ax = plt.gca()
    colors = COLORS * 100
    if prob is not None and boxes is not None:
      for p, (xmin, ymin, xmax, ymax), c in zip(prob, boxes.tolist(), colors):
          ax.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                    fill=False, color=c, linewidth=3))
          cl = p.argmax()
          text = f'{CLASSES[cl]}: {p[cl]:0.2f}'
          ax.text(xmin, ymin, text, fontsize=15,
                  bbox=dict(facecolor='yellow', alpha=0.5))
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## Load an image for a demo

# %%
model = torch.hub.load('facebookresearch/detr', 'detr_resnet50', pretrained=True)
model.eval()

# %%
from PIL import Image
import requests

url = 'http://images.cocodataset.org/train2017/000000310645.jpg'
im = Image.open(requests.get(url, stream=True).raw)

# %%
# mean-std normalize the input image (batch-size: 1)
img = transform(im).unsqueeze(0)

# propagate through the model
outputs = model(img)

# %%
for threshold in [0.9, 0.7, 0.0]:
  
  probas_to_keep, bboxes_scaled = filter_bboxes_from_outputs(outputs,
                                                            threshold=threshold)

  plot_results(im, probas_to_keep, bboxes_scaled)

# %% [markdown]
# NB: if the threshold is equal to zero, then you will see all of the 100 query slots. The zero-threshold is only used for illustration. In usual cases, most query slots have a low confidence score, so that irrelevant query slots would be pruned with a higher threshold, such as 0.7 or 0.9.
#
# Reference: https://github.com/facebookresearch/detr/issues/9#issuecomment-635357693
#
# NB²: For fine-tuning purposes, we cannot change the number of query slots.
#
# > If you're fine-tuning, I don't recommend changing the number of queries on the fly, it is extremely unlikely to work out of the box. In this case you're probably better off retraining from scratch (you can change the --num_queries arg from our training script).
#
# Reference: https://github.com/facebookresearch/detr/issues/9#issuecomment-636407752

# %% [markdown]
# ## Load pre-trained weights
#
# Load a check-point (urls can be found [here](https://github.com/facebookresearch/detr#model-zoo)), then remove the classification head.

# %%
# %cd /content/

# !rm -rf detr
# !git clone https://github.com/woctezuma/detr.git

# %cd detr/

# !git checkout finetune

# %cd ..

# %%
# Get pretrained weights
checkpoint = torch.hub.load_state_dict_from_url(
            url='https://dl.fbaipublicfiles.com/detr/detr-r50-e632da11.pth',
            map_location='cpu',
            check_hash=True)

# Remove class weights
del checkpoint["model"]["class_embed.weight"]
del checkpoint["model"]["class_embed.bias"]

# Save
torch.save(checkpoint,
           'detr/detr-r50_no-class-head.pth')

# %% [markdown]
# ## Prepare the dataset for fine-tuning
#
# The `balloon` dataset will be used. It is featured here and uses VIA format:
# -   https://github.com/matterport/Mask_RCNN/tree/master/samples/balloon

# %% [markdown]
# ## Check the dataset after it was pre-processed for fine-tuning
#
# To verify the data loading is correct, let's visualize the annotations of randomly selected samples in the training set:
# -   Demo of COCO API: https://github.com/cocodataset/cocoapi/blob/master/PythonAPI/pycocoDemo.ipynb

# %%
# %matplotlib inline
import pycocotools.coco as coco
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
dataDir='custom/'
dataType='train2017'
annFile='{}annotations/custom_train.json'.format(dataDir)

# %%
# initialize COCO api for instance annotations
coco=COCO(annFile)

# %%
# display COCO categories and supercategories
cats = coco.loadCats(coco.getCatIds())

nms=[cat['name'] for cat in cats]
print('Categories: {}'.format(nms))

nms = set([cat['supercategory'] for cat in cats])
print('Super-categories: {}'.format(nms))

# %%
# load and display image
catIds = coco.getCatIds(catNms=['butter'])
imgIds = coco.getImgIds(catIds=catIds )

# %%
img_id = imgIds[np.random.randint(0,len(imgIds))]
print('Image n°{}'.format(img_id))

img = coco.loadImgs(img_id)[0]

img_name = '%s/%s/%s'%(dataDir, dataType, img['file_name'])
print('Image name: {}'.format(img_name))

I = io.imread(img_name)
plt.figure()
plt.imshow(I)

# %%
annIds = coco.getAnnIds(imgIds=img['id'], catIds=catIds)
anns = coco.loadAnns(annIds)

# %%
# load and display instance annotations
plt.imshow(I)
coco.showAnns(anns, draw_bbox=False)

# %%
plt.imshow(I)
coco.showAnns(anns, draw_bbox=True)

# %% [markdown]
# ## Fine-tuning
#
# -   Instructions appear in [a Github Gist](https://gist.github.com/woctezuma/e9f8f9fe1737987351582e9441c46b5d).
#
# NB: There is a `--frozen_weights` argument. However,
# i) I have yet to figure out how it is used,
# ii) it is of no use for box detection. Indeed, "frozen training is meant for segmentation only" (as mentioned at this [line](https://github.com/facebookresearch/detr/blob/f4cdc542de34de771da8b9189742e5465f5220cd/main.py#L110) of the source-code).

# %% [markdown]
# ### Boilerplate variables
#
# **Caveat**: the parameter name `num_classes` is misleading. It is actually the ID which DETR will reserve for **its own** `no_object` class.
#
# It should be set to one plus the highest class ID in your dataset.
#
# For instance, if you have one class (balloon):
# - if you used the index n°0 for this class, then `max_id = 0` and `num_classes = max_id+1 = 1`
# - if you used the index n°1 for this class, then `max_id = 1` and `num_classes = max_id+1 = 2`
#
# Reference: https://github.com/facebookresearch/detr/issues/108#issuecomment-650269223

# %%
num_classes = 5

finetuned_classes = [
    'butter', 'cottage', 'milk', 'mustard', 'cream'
]

print('Parameter num_classes: {}'.format(num_classes))
print('Fine-tuned classes: {}'.format(finetuned_classes))
# Out:
# Parameter num_classes: 5
# Fine-tuned classes: ['butter', 'cottage', 'milk', 'mustard', 'cream']

# %% [markdown]
# **Caveat**: below, we override the value of `num_classes` (hard-coded to 2 for the `custom` dataset in my `finetune` branch of DETR) in case `first_class_index = 0` instead of `first_class_index = 1` (default value).

# %%
# !python3 detr/main.py \
  --dataset_file "custom" \
  --coco_path "custom/" \
  --output_dir "outputs/36epoch_new" \
  --resume "outputs/36epoch/checkpoint.pth" \
  --num_classes $num_classes \
  --epoch 40 \
  --batch_size 16 \
  --device "cpu"
# Out:
# Not using distributed mode
# git:
#   sha: 3cda3529921efb8870d0b49db7b30aa8477ae359, status: clean, branch: finetune
#
# Namespace(lr=0.0001, lr_backbone=1e-05, batch_size=16, weight_decay=0.0001, epochs=40, lr_drop=200, clip_max_norm=0.1, frozen_weights=None, backbone='resnet50', dilation=False, position_embedding='sine', enc_layers=6, dec_layers=6, dim_feedforward=2048, hidden_dim=256, dropout=0.1, nheads=8, num_queries=100, pre_norm=False, masks=False, aux_loss=True, set_cost_class=1, set_cost_bbox=5, set_cost_giou=2, mask_loss_coef=1, dice_loss_coef=1, bbox_loss_coef=5, giou_loss_coef=2, eos_coef=0.1, num_classes=5, dataset_file='custom', coco_path='custom/', coco_panoptic_path=None, remove_difficult=False, output_dir='outputs/36epoch_new', device='cpu', seed=42, resume='outputs/36epoch/checkpoint.pth', start_epoch=0, eval=False, num_workers=2, world_size=1, dist_url='env://', distributed=False)
# /Users/coralavital/Desktop/vscode/finetune-detr/venv/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/coralavital/Desktop/vscode/finetune-detr/venv/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# number of params: 41280266
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Start training
# Epoch: [36]  [  0/130]  eta: 3:47:25  lr: 0.000100  class_error: 0.00  loss: 1.5914 (1.5914)  loss_ce: 0.0066 (0.0066)  loss_bbox: 0.0936 (0.0936)  loss_giou: 0.1338 (0.1338)  loss_ce_0: 0.0357 (0.0357)  loss_bbox_0: 0.1413 (0.1413)  loss_giou_0: 0.2017 (0.2017)  loss_ce_1: 0.0174 (0.0174)  loss_bbox_1: 0.1141 (0.1141)  loss_giou_1: 0.1459 (0.1459)  loss_ce_2: 0.0082 (0.0082)  loss_bbox_2: 0.1040 (0.1040)  loss_giou_2: 0.1386 (0.1386)  loss_ce_3: 0.0068 (0.0068)  loss_bbox_3: 0.0880 (0.0880)  loss_giou_3: 0.1219 (0.1219)  loss_ce_4: 0.0068 (0.0068)  loss_bbox_4: 0.0936 (0.0936)  loss_giou_4: 0.1332 (0.1332)  loss_ce_unscaled: 0.0066 (0.0066)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0187 (0.0187)  loss_giou_unscaled: 0.0669 (0.0669)  cardinality_error_unscaled: 0.0625 (0.0625)  loss_ce_0_unscaled: 0.0357 (0.0357)  loss_bbox_0_unscaled: 0.0283 (0.0283)  loss_giou_0_unscaled: 0.1009 (0.1009)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.0174 (0.0174)  loss_bbox_1_unscaled: 0.0228 (0.0228)  loss_giou_1_unscaled: 0.0730 (0.0730)  cardinality_error_1_unscaled: 0.4375 (0.4375)  loss_ce_2_unscaled: 0.0082 (0.0082)  loss_bbox_2_unscaled: 0.0208 (0.0208)  loss_giou_2_unscaled: 0.0693 (0.0693)  cardinality_error_2_unscaled: 0.1250 (0.1250)  loss_ce_3_unscaled: 0.0068 (0.0068)  loss_bbox_3_unscaled: 0.0176 (0.0176)  loss_giou_3_unscaled: 0.0610 (0.0610)  cardinality_error_3_unscaled: 0.0625 (0.0625)  loss_ce_4_unscaled: 0.0068 (0.0068)  loss_bbox_4_unscaled: 0.0187 (0.0187)  loss_giou_4_unscaled: 0.0666 (0.0666)  cardinality_error_4_unscaled: 0.0625 (0.0625)  time: 104.9640  data: 6.8284
# Epoch: [36]  [ 10/130]  eta: 3:25:54  lr: 0.000100  class_error: 5.00  loss: 1.5296 (1.5505)  loss_ce: 0.0073 (0.0137)  loss_bbox: 0.0825 (0.0818)  loss_giou: 0.1297 (0.1298)  loss_ce_0: 0.0396 (0.0447)  loss_bbox_0: 0.1195 (0.1184)  loss_giou_0: 0.1792 (0.1845)  loss_ce_1: 0.0192 (0.0280)  loss_bbox_1: 0.0928 (0.0963)  loss_giou_1: 0.1459 (0.1434)  loss_ce_2: 0.0086 (0.0174)  loss_bbox_2: 0.0883 (0.0924)  loss_giou_2: 0.1386 (0.1423)  loss_ce_3: 0.0082 (0.0154)  loss_bbox_3: 0.0830 (0.0850)  loss_giou_3: 0.1226 (0.1337)  loss_ce_4: 0.0076 (0.0139)  loss_bbox_4: 0.0817 (0.0808)  loss_giou_4: 0.1270 (0.1290)  loss_ce_unscaled: 0.0073 (0.0137)  class_error_unscaled: 0.0000 (2.1564)  loss_bbox_unscaled: 0.0165 (0.0164)  loss_giou_unscaled: 0.0648 (0.0649)  cardinality_error_unscaled: 0.0625 (0.1136)  loss_ce_0_unscaled: 0.0396 (0.0447)  loss_bbox_0_unscaled: 0.0239 (0.0237)  loss_giou_0_unscaled: 0.0896 (0.0922)  cardinality_error_0_unscaled: 1.0000 (0.9545)  loss_ce_1_unscaled: 0.0192 (0.0280)  loss_bbox_1_unscaled: 0.0186 (0.0193)  loss_giou_1_unscaled: 0.0730 (0.0717)  cardinality_error_1_unscaled: 0.4375 (0.4375)  loss_ce_2_unscaled: 0.0086 (0.0174)  loss_bbox_2_unscaled: 0.0177 (0.0185)  loss_giou_2_unscaled: 0.0693 (0.0712)  cardinality_error_2_unscaled: 0.1250 (0.1136)  loss_ce_3_unscaled: 0.0082 (0.0154)  loss_bbox_3_unscaled: 0.0166 (0.0170)  loss_giou_3_unscaled: 0.0613 (0.0669)  cardinality_error_3_unscaled: 0.0625 (0.0852)  loss_ce_4_unscaled: 0.0076 (0.0139)  loss_bbox_4_unscaled: 0.0163 (0.0162)  loss_giou_4_unscaled: 0.0635 (0.0645)  cardinality_error_4_unscaled: 0.0625 (0.1136)  time: 102.9551  data: 0.6388
# Epoch: [36]  [ 20/130]  eta: 2:53:46  lr: 0.000100  class_error: 0.00  loss: 1.5271 (1.5914)  loss_ce: 0.0064 (0.0146)  loss_bbox: 0.0798 (0.0829)  loss_giou: 0.1297 (0.1332)  loss_ce_0: 0.0435 (0.0483)  loss_bbox_0: 0.1195 (0.1209)  loss_giou_0: 0.1794 (0.1894)  loss_ce_1: 0.0206 (0.0266)  loss_bbox_1: 0.0960 (0.0988)  loss_giou_1: 0.1493 (0.1512)  loss_ce_2: 0.0082 (0.0185)  loss_bbox_2: 0.0878 (0.0927)  loss_giou_2: 0.1449 (0.1458)  loss_ce_3: 0.0076 (0.0147)  loss_bbox_3: 0.0827 (0.0866)  loss_giou_3: 0.1277 (0.1376)  loss_ce_4: 0.0068 (0.0147)  loss_bbox_4: 0.0794 (0.0822)  loss_giou_4: 0.1265 (0.1325)  loss_ce_unscaled: 0.0064 (0.0146)  class_error_unscaled: 0.0000 (1.9412)  loss_bbox_unscaled: 0.0160 (0.0166)  loss_giou_unscaled: 0.0648 (0.0666)  cardinality_error_unscaled: 0.0625 (0.0863)  loss_ce_0_unscaled: 0.0435 (0.0483)  loss_bbox_0_unscaled: 0.0239 (0.0242)  loss_giou_0_unscaled: 0.0897 (0.0947)  cardinality_error_0_unscaled: 1.0625 (1.1339)  loss_ce_1_unscaled: 0.0206 (0.0266)  loss_bbox_1_unscaled: 0.0192 (0.0198)  loss_giou_1_unscaled: 0.0746 (0.0756)  cardinality_error_1_unscaled: 0.4375 (0.4494)  loss_ce_2_unscaled: 0.0082 (0.0185)  loss_bbox_2_unscaled: 0.0176 (0.0185)  loss_giou_2_unscaled: 0.0725 (0.0729)  cardinality_error_2_unscaled: 0.0625 (0.1131)  loss_ce_3_unscaled: 0.0076 (0.0147)  loss_bbox_3_unscaled: 0.0165 (0.0173)  loss_giou_3_unscaled: 0.0638 (0.0688)  cardinality_error_3_unscaled: 0.0625 (0.0774)  loss_ce_4_unscaled: 0.0068 (0.0147)  loss_bbox_4_unscaled: 0.0159 (0.0164)  loss_giou_4_unscaled: 0.0633 (0.0663)  cardinality_error_4_unscaled: 0.0625 (0.0863)  time: 94.2809  data: 0.0185
# Epoch: [36]  [ 30/130]  eta: 2:40:07  lr: 0.000100  class_error: 0.00  loss: 1.5709 (1.6184)  loss_ce: 0.0054 (0.0139)  loss_bbox: 0.0829 (0.0860)  loss_giou: 0.1403 (0.1372)  loss_ce_0: 0.0476 (0.0513)  loss_bbox_0: 0.1220 (0.1205)  loss_giou_0: 0.1853 (0.1895)  loss_ce_1: 0.0237 (0.0280)  loss_bbox_1: 0.0960 (0.0977)  loss_giou_1: 0.1475 (0.1511)  loss_ce_2: 0.0082 (0.0183)  loss_bbox_2: 0.0937 (0.0951)  loss_giou_2: 0.1487 (0.1482)  loss_ce_3: 0.0051 (0.0150)  loss_bbox_3: 0.0870 (0.0888)  loss_giou_3: 0.1421 (0.1409)  loss_ce_4: 0.0056 (0.0158)  loss_bbox_4: 0.0808 (0.0849)  loss_giou_4: 0.1387 (0.1363)  loss_ce_unscaled: 0.0054 (0.0139)  class_error_unscaled: 0.0000 (1.9771)  loss_bbox_unscaled: 0.0166 (0.0172)  loss_giou_unscaled: 0.0702 (0.0686)  cardinality_error_unscaled: 0.0000 (0.0948)  loss_ce_0_unscaled: 0.0476 (0.0513)  loss_bbox_0_unscaled: 0.0244 (0.0241)  loss_giou_0_unscaled: 0.0927 (0.0947)  cardinality_error_0_unscaled: 1.2500 (1.1613)  loss_ce_1_unscaled: 0.0237 (0.0280)  loss_bbox_1_unscaled: 0.0192 (0.0195)  loss_giou_1_unscaled: 0.0737 (0.0756)  cardinality_error_1_unscaled: 0.5625 (0.5101)  loss_ce_2_unscaled: 0.0082 (0.0183)  loss_bbox_2_unscaled: 0.0187 (0.0190)  loss_giou_2_unscaled: 0.0744 (0.0741)  cardinality_error_2_unscaled: 0.1250 (0.1250)  loss_ce_3_unscaled: 0.0051 (0.0150)  loss_bbox_3_unscaled: 0.0174 (0.0178)  loss_giou_3_unscaled: 0.0711 (0.0704)  cardinality_error_3_unscaled: 0.0625 (0.0907)  loss_ce_4_unscaled: 0.0056 (0.0158)  loss_bbox_4_unscaled: 0.0162 (0.0170)  loss_giou_4_unscaled: 0.0693 (0.0682)  cardinality_error_4_unscaled: 0.0000 (0.0927)  time: 92.2957  data: 0.0179
# Epoch: [36]  [ 40/130]  eta: 2:30:40  lr: 0.000100  class_error: 0.00  loss: 1.6366 (1.6466)  loss_ce: 0.0099 (0.0154)  loss_bbox: 0.0860 (0.0883)  loss_giou: 0.1395 (0.1375)  loss_ce_0: 0.0574 (0.0540)  loss_bbox_0: 0.1271 (0.1225)  loss_giou_0: 0.1830 (0.1877)  loss_ce_1: 0.0328 (0.0309)  loss_bbox_1: 0.0995 (0.1004)  loss_giou_1: 0.1533 (0.1531)  loss_ce_2: 0.0133 (0.0202)  loss_bbox_2: 0.0960 (0.0980)  loss_giou_2: 0.1493 (0.1491)  loss_ce_3: 0.0124 (0.0162)  loss_bbox_3: 0.0932 (0.0917)  loss_giou_3: 0.1426 (0.1420)  loss_ce_4: 0.0151 (0.0174)  loss_bbox_4: 0.0882 (0.0861)  loss_giou_4: 0.1403 (0.1361)  loss_ce_unscaled: 0.0099 (0.0154)  class_error_unscaled: 0.0000 (2.6020)  loss_bbox_unscaled: 0.0172 (0.0177)  loss_giou_unscaled: 0.0697 (0.0687)  cardinality_error_unscaled: 0.0625 (0.0869)  loss_ce_0_unscaled: 0.0574 (0.0540)  loss_bbox_0_unscaled: 0.0254 (0.0245)  loss_giou_0_unscaled: 0.0915 (0.0938)  cardinality_error_0_unscaled: 1.2500 (1.1845)  loss_ce_1_unscaled: 0.0328 (0.0309)  loss_bbox_1_unscaled: 0.0199 (0.0201)  loss_giou_1_unscaled: 0.0767 (0.0766)  cardinality_error_1_unscaled: 0.6250 (0.5305)  loss_ce_2_unscaled: 0.0133 (0.0202)  loss_bbox_2_unscaled: 0.0192 (0.0196)  loss_giou_2_unscaled: 0.0747 (0.0746)  cardinality_error_2_unscaled: 0.1875 (0.1357)  loss_ce_3_unscaled: 0.0124 (0.0162)  loss_bbox_3_unscaled: 0.0186 (0.0183)  loss_giou_3_unscaled: 0.0713 (0.0710)  cardinality_error_3_unscaled: 0.0625 (0.0899)  loss_ce_4_unscaled: 0.0151 (0.0174)  loss_bbox_4_unscaled: 0.0176 (0.0172)  loss_giou_4_unscaled: 0.0701 (0.0681)  cardinality_error_4_unscaled: 0.0000 (0.0869)  time: 106.3847  data: 0.0208
# Epoch: [36]  [ 50/130]  eta: 2:18:22  lr: 0.000100  class_error: 0.00  loss: 1.5038 (1.6220)  loss_ce: 0.0069 (0.0148)  loss_bbox: 0.0848 (0.0884)  loss_giou: 0.1226 (0.1346)  loss_ce_0: 0.0474 (0.0520)  loss_bbox_0: 0.1215 (0.1219)  loss_giou_0: 0.1689 (0.1837)  loss_ce_1: 0.0285 (0.0303)  loss_bbox_1: 0.0995 (0.1009)  loss_giou_1: 0.1426 (0.1502)  loss_ce_2: 0.0087 (0.0184)  loss_bbox_2: 0.0918 (0.0985)  loss_giou_2: 0.1301 (0.1456)  loss_ce_3: 0.0073 (0.0156)  loss_bbox_3: 0.0893 (0.0915)  loss_giou_3: 0.1222 (0.1387)  loss_ce_4: 0.0094 (0.0164)  loss_bbox_4: 0.0882 (0.0868)  loss_giou_4: 0.1204 (0.1338)  loss_ce_unscaled: 0.0069 (0.0148)  class_error_unscaled: 0.0000 (2.5439)  loss_bbox_unscaled: 0.0170 (0.0177)  loss_giou_unscaled: 0.0613 (0.0673)  cardinality_error_unscaled: 0.0625 (0.0846)  loss_ce_0_unscaled: 0.0474 (0.0520)  loss_bbox_0_unscaled: 0.0243 (0.0244)  loss_giou_0_unscaled: 0.0844 (0.0919)  cardinality_error_0_unscaled: 1.1250 (1.1593)  loss_ce_1_unscaled: 0.0285 (0.0303)  loss_bbox_1_unscaled: 0.0199 (0.0202)  loss_giou_1_unscaled: 0.0713 (0.0751)  cardinality_error_1_unscaled: 0.5625 (0.5355)  loss_ce_2_unscaled: 0.0087 (0.0184)  loss_bbox_2_unscaled: 0.0184 (0.0197)  loss_giou_2_unscaled: 0.0651 (0.0728)  cardinality_error_2_unscaled: 0.1250 (0.1324)  loss_ce_3_unscaled: 0.0073 (0.0156)  loss_bbox_3_unscaled: 0.0179 (0.0183)  loss_giou_3_unscaled: 0.0611 (0.0693)  cardinality_error_3_unscaled: 0.0625 (0.0895)  loss_ce_4_unscaled: 0.0094 (0.0164)  loss_bbox_4_unscaled: 0.0176 (0.0174)  loss_giou_4_unscaled: 0.0602 (0.0669)  cardinality_error_4_unscaled: 0.0625 (0.0846)  time: 115.7283  data: 0.0236
# Epoch: [36]  [ 60/130]  eta: 2:03:59  lr: 0.000100  class_error: 0.00  loss: 1.4955 (1.6337)  loss_ce: 0.0050 (0.0166)  loss_bbox: 0.0831 (0.0891)  loss_giou: 0.1226 (0.1354)  loss_ce_0: 0.0422 (0.0529)  loss_bbox_0: 0.1123 (0.1214)  loss_giou_0: 0.1761 (0.1834)  loss_ce_1: 0.0213 (0.0306)  loss_bbox_1: 0.0947 (0.1016)  loss_giou_1: 0.1441 (0.1512)  loss_ce_2: 0.0072 (0.0184)  loss_bbox_2: 0.0907 (0.0990)  loss_giou_2: 0.1290 (0.1456)  loss_ce_3: 0.0047 (0.0161)  loss_bbox_3: 0.0878 (0.0931)  loss_giou_3: 0.1218 (0.1400)  loss_ce_4: 0.0048 (0.0170)  loss_bbox_4: 0.0847 (0.0877)  loss_giou_4: 0.1208 (0.1347)  loss_ce_unscaled: 0.0050 (0.0166)  class_error_unscaled: 0.0000 (2.6453)  loss_bbox_unscaled: 0.0166 (0.0178)  loss_giou_unscaled: 0.0613 (0.0677)  cardinality_error_unscaled: 0.0625 (0.0830)  loss_ce_0_unscaled: 0.0422 (0.0529)  loss_bbox_0_unscaled: 0.0225 (0.0243)  loss_giou_0_unscaled: 0.0880 (0.0917)  cardinality_error_0_unscaled: 1.0625 (1.1240)  loss_ce_1_unscaled: 0.0213 (0.0306)  loss_bbox_1_unscaled: 0.0189 (0.0203)  loss_giou_1_unscaled: 0.0721 (0.0756)  cardinality_error_1_unscaled: 0.5000 (0.5123)  loss_ce_2_unscaled: 0.0072 (0.0184)  loss_bbox_2_unscaled: 0.0181 (0.0198)  loss_giou_2_unscaled: 0.0645 (0.0728)  cardinality_error_2_unscaled: 0.1250 (0.1270)  loss_ce_3_unscaled: 0.0047 (0.0161)  loss_bbox_3_unscaled: 0.0176 (0.0186)  loss_giou_3_unscaled: 0.0609 (0.0700)  cardinality_error_3_unscaled: 0.0625 (0.0850)  loss_ce_4_unscaled: 0.0048 (0.0170)  loss_bbox_4_unscaled: 0.0169 (0.0175)  loss_giou_4_unscaled: 0.0604 (0.0674)  cardinality_error_4_unscaled: 0.0625 (0.0820)  time: 118.2440  data: 0.0236
# Epoch: [36]  [ 70/130]  eta: 1:44:49  lr: 0.000100  class_error: 0.00  loss: 1.5804 (1.6419)  loss_ce: 0.0050 (0.0167)  loss_bbox: 0.0831 (0.0897)  loss_giou: 0.1325 (0.1349)  loss_ce_0: 0.0396 (0.0533)  loss_bbox_0: 0.1255 (0.1231)  loss_giou_0: 0.1830 (0.1837)  loss_ce_1: 0.0197 (0.0311)  loss_bbox_1: 0.0977 (0.1022)  loss_giou_1: 0.1495 (0.1520)  loss_ce_2: 0.0071 (0.0185)  loss_bbox_2: 0.0922 (0.0997)  loss_giou_2: 0.1426 (0.1459)  loss_ce_3: 0.0050 (0.0159)  loss_bbox_3: 0.0921 (0.0944)  loss_giou_3: 0.1429 (0.1404)  loss_ce_4: 0.0050 (0.0170)  loss_bbox_4: 0.0847 (0.0886)  loss_giou_4: 0.1335 (0.1347)  loss_ce_unscaled: 0.0050 (0.0167)  class_error_unscaled: 0.0000 (2.5700)  loss_bbox_unscaled: 0.0166 (0.0179)  loss_giou_unscaled: 0.0662 (0.0675)  cardinality_error_unscaled: 0.0625 (0.0766)  loss_ce_0_unscaled: 0.0396 (0.0533)  loss_bbox_0_unscaled: 0.0251 (0.0246)  loss_giou_0_unscaled: 0.0915 (0.0918)  cardinality_error_0_unscaled: 0.8125 (1.0695)  loss_ce_1_unscaled: 0.0197 (0.0311)  loss_bbox_1_unscaled: 0.0195 (0.0204)  loss_giou_1_unscaled: 0.0747 (0.0760)  cardinality_error_1_unscaled: 0.3750 (0.4921)  loss_ce_2_unscaled: 0.0071 (0.0185)  loss_bbox_2_unscaled: 0.0184 (0.0199)  loss_giou_2_unscaled: 0.0713 (0.0730)  cardinality_error_2_unscaled: 0.0625 (0.1188)  loss_ce_3_unscaled: 0.0050 (0.0159)  loss_bbox_3_unscaled: 0.0184 (0.0189)  loss_giou_3_unscaled: 0.0714 (0.0702)  cardinality_error_3_unscaled: 0.0625 (0.0792)  loss_ce_4_unscaled: 0.0050 (0.0170)  loss_bbox_4_unscaled: 0.0169 (0.0177)  loss_giou_4_unscaled: 0.0667 (0.0674)  cardinality_error_4_unscaled: 0.0625 (0.0748)  time: 107.4577  data: 0.0206
# Epoch: [36]  [ 80/130]  eta: 1:27:19  lr: 0.000100  class_error: 13.64  loss: 1.5974 (1.6678)  loss_ce: 0.0065 (0.0185)  loss_bbox: 0.0892 (0.0903)  loss_giou: 0.1325 (0.1365)  loss_ce_0: 0.0405 (0.0534)  loss_bbox_0: 0.1268 (0.1245)  loss_giou_0: 0.1893 (0.1869)  loss_ce_1: 0.0224 (0.0316)  loss_bbox_1: 0.1019 (0.1034)  loss_giou_1: 0.1546 (0.1543)  loss_ce_2: 0.0090 (0.0200)  loss_bbox_2: 0.0967 (0.1005)  loss_giou_2: 0.1483 (0.1479)  loss_ce_3: 0.0059 (0.0178)  loss_bbox_3: 0.0932 (0.0952)  loss_giou_3: 0.1427 (0.1418)  loss_ce_4: 0.0065 (0.0187)  loss_bbox_4: 0.0861 (0.0897)  loss_giou_4: 0.1388 (0.1369)  loss_ce_unscaled: 0.0065 (0.0185)  class_error_unscaled: 0.0000 (2.6661)  loss_bbox_unscaled: 0.0178 (0.0181)  loss_giou_unscaled: 0.0662 (0.0682)  cardinality_error_unscaled: 0.0625 (0.0818)  loss_ce_0_unscaled: 0.0405 (0.0534)  loss_bbox_0_unscaled: 0.0254 (0.0249)  loss_giou_0_unscaled: 0.0946 (0.0934)  cardinality_error_0_unscaled: 0.7500 (1.0309)  loss_ce_1_unscaled: 0.0224 (0.0316)  loss_bbox_1_unscaled: 0.0204 (0.0207)  loss_giou_1_unscaled: 0.0773 (0.0772)  cardinality_error_1_unscaled: 0.3750 (0.4907)  loss_ce_2_unscaled: 0.0090 (0.0200)  loss_bbox_2_unscaled: 0.0193 (0.0201)  loss_giou_2_unscaled: 0.0741 (0.0739)  cardinality_error_2_unscaled: 0.0625 (0.1204)  loss_ce_3_unscaled: 0.0059 (0.0178)  loss_bbox_3_unscaled: 0.0186 (0.0190)  loss_giou_3_unscaled: 0.0714 (0.0709)  cardinality_error_3_unscaled: 0.0625 (0.0841)  loss_ce_4_unscaled: 0.0065 (0.0187)  loss_bbox_4_unscaled: 0.0172 (0.0179)  loss_giou_4_unscaled: 0.0694 (0.0685)  cardinality_error_4_unscaled: 0.0625 (0.0772)  time: 100.2458  data: 0.0182
# Epoch: [36]  [ 90/130]  eta: 1:09:37  lr: 0.000100  class_error: 0.00  loss: 1.5678 (1.6539)  loss_ce: 0.0077 (0.0180)  loss_bbox: 0.0853 (0.0890)  loss_giou: 0.1277 (0.1359)  loss_ce_0: 0.0405 (0.0523)  loss_bbox_0: 0.1190 (0.1239)  loss_giou_0: 0.1936 (0.1875)  loss_ce_1: 0.0201 (0.0312)  loss_bbox_1: 0.0941 (0.1021)  loss_giou_1: 0.1524 (0.1533)  loss_ce_2: 0.0104 (0.0195)  loss_bbox_2: 0.0901 (0.0988)  loss_giou_2: 0.1413 (0.1468)  loss_ce_3: 0.0081 (0.0173)  loss_bbox_3: 0.0859 (0.0938)  loss_giou_3: 0.1333 (0.1409)  loss_ce_4: 0.0073 (0.0180)  loss_bbox_4: 0.0846 (0.0888)  loss_giou_4: 0.1343 (0.1367)  loss_ce_unscaled: 0.0077 (0.0180)  class_error_unscaled: 0.0000 (2.5544)  loss_bbox_unscaled: 0.0171 (0.0178)  loss_giou_unscaled: 0.0638 (0.0680)  cardinality_error_unscaled: 0.0625 (0.0845)  loss_ce_0_unscaled: 0.0405 (0.0523)  loss_bbox_0_unscaled: 0.0238 (0.0248)  loss_giou_0_unscaled: 0.0968 (0.0938)  cardinality_error_0_unscaled: 0.7500 (1.0254)  loss_ce_1_unscaled: 0.0201 (0.0312)  loss_bbox_1_unscaled: 0.0188 (0.0204)  loss_giou_1_unscaled: 0.0762 (0.0767)  cardinality_error_1_unscaled: 0.4375 (0.4883)  loss_ce_2_unscaled: 0.0104 (0.0195)  loss_bbox_2_unscaled: 0.0180 (0.0198)  loss_giou_2_unscaled: 0.0706 (0.0734)  cardinality_error_2_unscaled: 0.1250 (0.1250)  loss_ce_3_unscaled: 0.0081 (0.0173)  loss_bbox_3_unscaled: 0.0172 (0.0188)  loss_giou_3_unscaled: 0.0666 (0.0705)  cardinality_error_3_unscaled: 0.1250 (0.0872)  loss_ce_4_unscaled: 0.0073 (0.0180)  loss_bbox_4_unscaled: 0.0169 (0.0178)  loss_giou_4_unscaled: 0.0671 (0.0684)  cardinality_error_4_unscaled: 0.0625 (0.0797)  time: 103.0601  data: 0.0185
# Epoch: [36]  [100/130]  eta: 0:51:49  lr: 0.000100  class_error: 4.76  loss: 1.5678 (1.6543)  loss_ce: 0.0085 (0.0186)  loss_bbox: 0.0817 (0.0891)  loss_giou: 0.1375 (0.1366)  loss_ce_0: 0.0412 (0.0522)  loss_bbox_0: 0.1190 (0.1242)  loss_giou_0: 0.1869 (0.1875)  loss_ce_1: 0.0201 (0.0317)  loss_bbox_1: 0.0920 (0.1016)  loss_giou_1: 0.1498 (0.1525)  loss_ce_2: 0.0112 (0.0197)  loss_bbox_2: 0.0868 (0.0985)  loss_giou_2: 0.1446 (0.1467)  loss_ce_3: 0.0082 (0.0177)  loss_bbox_3: 0.0816 (0.0932)  loss_giou_3: 0.1333 (0.1403)  loss_ce_4: 0.0080 (0.0183)  loss_bbox_4: 0.0845 (0.0890)  loss_giou_4: 0.1345 (0.1368)  loss_ce_unscaled: 0.0085 (0.0186)  class_error_unscaled: 0.0000 (2.6057)  loss_bbox_unscaled: 0.0163 (0.0178)  loss_giou_unscaled: 0.0688 (0.0683)  cardinality_error_unscaled: 0.1250 (0.0934)  loss_ce_0_unscaled: 0.0412 (0.0522)  loss_bbox_0_unscaled: 0.0238 (0.0248)  loss_giou_0_unscaled: 0.0935 (0.0938)  cardinality_error_0_unscaled: 0.8750 (1.0179)  loss_ce_1_unscaled: 0.0201 (0.0317)  loss_bbox_1_unscaled: 0.0184 (0.0203)  loss_giou_1_unscaled: 0.0749 (0.0762)  cardinality_error_1_unscaled: 0.3750 (0.4790)  loss_ce_2_unscaled: 0.0112 (0.0197)  loss_bbox_2_unscaled: 0.0174 (0.0197)  loss_giou_2_unscaled: 0.0723 (0.0733)  cardinality_error_2_unscaled: 0.1250 (0.1300)  loss_ce_3_unscaled: 0.0082 (0.0177)  loss_bbox_3_unscaled: 0.0163 (0.0186)  loss_giou_3_unscaled: 0.0666 (0.0702)  cardinality_error_3_unscaled: 0.1250 (0.0953)  loss_ce_4_unscaled: 0.0080 (0.0183)  loss_bbox_4_unscaled: 0.0169 (0.0178)  loss_giou_4_unscaled: 0.0672 (0.0684)  cardinality_error_4_unscaled: 0.1250 (0.0885)  time: 99.0581  data: 0.0187
# Epoch: [36]  [110/130]  eta: 0:34:30  lr: 0.000100  class_error: 0.00  loss: 1.5790 (1.6468)  loss_ce: 0.0085 (0.0181)  loss_bbox: 0.0843 (0.0890)  loss_giou: 0.1356 (0.1362)  loss_ce_0: 0.0361 (0.0508)  loss_bbox_0: 0.1184 (0.1241)  loss_giou_0: 0.1823 (0.1873)  loss_ce_1: 0.0159 (0.0305)  loss_bbox_1: 0.0939 (0.1011)  loss_giou_1: 0.1498 (0.1528)  loss_ce_2: 0.0063 (0.0191)  loss_bbox_2: 0.0880 (0.0983)  loss_giou_2: 0.1447 (0.1462)  loss_ce_3: 0.0078 (0.0174)  loss_bbox_3: 0.0803 (0.0927)  loss_giou_3: 0.1343 (0.1400)  loss_ce_4: 0.0080 (0.0179)  loss_bbox_4: 0.0837 (0.0889)  loss_giou_4: 0.1348 (0.1366)  loss_ce_unscaled: 0.0085 (0.0181)  class_error_unscaled: 0.0000 (2.5444)  loss_bbox_unscaled: 0.0169 (0.0178)  loss_giou_unscaled: 0.0678 (0.0681)  cardinality_error_unscaled: 0.0625 (0.0895)  loss_ce_0_unscaled: 0.0361 (0.0508)  loss_bbox_0_unscaled: 0.0237 (0.0248)  loss_giou_0_unscaled: 0.0911 (0.0936)  cardinality_error_0_unscaled: 0.8750 (0.9989)  loss_ce_1_unscaled: 0.0159 (0.0305)  loss_bbox_1_unscaled: 0.0188 (0.0202)  loss_giou_1_unscaled: 0.0749 (0.0764)  cardinality_error_1_unscaled: 0.3125 (0.4617)  loss_ce_2_unscaled: 0.0063 (0.0191)  loss_bbox_2_unscaled: 0.0176 (0.0197)  loss_giou_2_unscaled: 0.0724 (0.0731)  cardinality_error_2_unscaled: 0.1250 (0.1244)  loss_ce_3_unscaled: 0.0078 (0.0174)  loss_bbox_3_unscaled: 0.0161 (0.0185)  loss_giou_3_unscaled: 0.0671 (0.0700)  cardinality_error_3_unscaled: 0.0625 (0.0901)  loss_ce_4_unscaled: 0.0080 (0.0179)  loss_bbox_4_unscaled: 0.0167 (0.0178)  loss_giou_4_unscaled: 0.0674 (0.0683)  cardinality_error_4_unscaled: 0.0625 (0.0845)  time: 99.5057  data: 0.0194
# Epoch: [36]  [120/130]  eta: 0:17:17  lr: 0.000100  class_error: 0.00  loss: 1.5542 (1.6612)  loss_ce: 0.0075 (0.0189)  loss_bbox: 0.0878 (0.0894)  loss_giou: 0.1316 (0.1374)  loss_ce_0: 0.0358 (0.0511)  loss_bbox_0: 0.1151 (0.1243)  loss_giou_0: 0.1776 (0.1887)  loss_ce_1: 0.0171 (0.0312)  loss_bbox_1: 0.0975 (0.1016)  loss_giou_1: 0.1563 (0.1538)  loss_ce_2: 0.0077 (0.0199)  loss_bbox_2: 0.0955 (0.0988)  loss_giou_2: 0.1393 (0.1474)  loss_ce_3: 0.0080 (0.0182)  loss_bbox_3: 0.0930 (0.0934)  loss_giou_3: 0.1355 (0.1414)  loss_ce_4: 0.0077 (0.0186)  loss_bbox_4: 0.0940 (0.0894)  loss_giou_4: 0.1348 (0.1378)  loss_ce_unscaled: 0.0075 (0.0189)  class_error_unscaled: 0.0000 (2.7963)  loss_bbox_unscaled: 0.0176 (0.0179)  loss_giou_unscaled: 0.0658 (0.0687)  cardinality_error_unscaled: 0.0625 (0.0966)  loss_ce_0_unscaled: 0.0358 (0.0511)  loss_bbox_0_unscaled: 0.0230 (0.0249)  loss_giou_0_unscaled: 0.0888 (0.0944)  cardinality_error_0_unscaled: 0.7500 (0.9819)  loss_ce_1_unscaled: 0.0171 (0.0312)  loss_bbox_1_unscaled: 0.0195 (0.0203)  loss_giou_1_unscaled: 0.0781 (0.0769)  cardinality_error_1_unscaled: 0.3125 (0.4514)  loss_ce_2_unscaled: 0.0077 (0.0199)  loss_bbox_2_unscaled: 0.0191 (0.0198)  loss_giou_2_unscaled: 0.0696 (0.0737)  cardinality_error_2_unscaled: 0.1250 (0.1312)  loss_ce_3_unscaled: 0.0080 (0.0182)  loss_bbox_3_unscaled: 0.0186 (0.0187)  loss_giou_3_unscaled: 0.0677 (0.0707)  cardinality_error_3_unscaled: 0.0625 (0.0950)  loss_ce_4_unscaled: 0.0077 (0.0186)  loss_bbox_4_unscaled: 0.0188 (0.0179)  loss_giou_4_unscaled: 0.0674 (0.0689)  cardinality_error_4_unscaled: 0.0625 (0.0919)  time: 104.0682  data: 0.0193
# Epoch: [36]  [129/130]  eta: 0:01:43  lr: 0.000100  class_error: 0.00  loss: 1.5414 (1.6504)  loss_ce: 0.0085 (0.0184)  loss_bbox: 0.0896 (0.0889)  loss_giou: 0.1257 (0.1363)  loss_ce_0: 0.0373 (0.0507)  loss_bbox_0: 0.1131 (0.1235)  loss_giou_0: 0.1835 (0.1880)  loss_ce_1: 0.0264 (0.0309)  loss_bbox_1: 0.0988 (0.1012)  loss_giou_1: 0.1563 (0.1536)  loss_ce_2: 0.0119 (0.0195)  loss_bbox_2: 0.0930 (0.0982)  loss_giou_2: 0.1414 (0.1466)  loss_ce_3: 0.0105 (0.0178)  loss_bbox_3: 0.0930 (0.0930)  loss_giou_3: 0.1355 (0.1403)  loss_ce_4: 0.0089 (0.0181)  loss_bbox_4: 0.0894 (0.0889)  loss_giou_4: 0.1280 (0.1367)  loss_ce_unscaled: 0.0085 (0.0184)  class_error_unscaled: 0.0000 (2.7051)  loss_bbox_unscaled: 0.0179 (0.0178)  loss_giou_unscaled: 0.0629 (0.0681)  cardinality_error_unscaled: 0.0625 (0.0942)  loss_ce_0_unscaled: 0.0373 (0.0507)  loss_bbox_0_unscaled: 0.0226 (0.0247)  loss_giou_0_unscaled: 0.0918 (0.0940)  cardinality_error_0_unscaled: 0.7500 (0.9750)  loss_ce_1_unscaled: 0.0264 (0.0309)  loss_bbox_1_unscaled: 0.0198 (0.0202)  loss_giou_1_unscaled: 0.0781 (0.0768)  cardinality_error_1_unscaled: 0.3125 (0.4490)  loss_ce_2_unscaled: 0.0119 (0.0195)  loss_bbox_2_unscaled: 0.0186 (0.0196)  loss_giou_2_unscaled: 0.0707 (0.0733)  cardinality_error_2_unscaled: 0.1250 (0.1279)  loss_ce_3_unscaled: 0.0105 (0.0178)  loss_bbox_3_unscaled: 0.0186 (0.0186)  loss_giou_3_unscaled: 0.0677 (0.0702)  cardinality_error_3_unscaled: 0.1250 (0.0947)  loss_ce_4_unscaled: 0.0089 (0.0181)  loss_bbox_4_unscaled: 0.0179 (0.0178)  loss_giou_4_unscaled: 0.0640 (0.0684)  cardinality_error_4_unscaled: 0.0625 (0.0894)  time: 101.7697  data: 0.0196
# Epoch: [36] Total time: 3:43:58 (103.3738 s / it)
# Averaged stats: lr: 0.000100  class_error: 0.00  loss: 1.5414 (1.6504)  loss_ce: 0.0085 (0.0184)  loss_bbox: 0.0896 (0.0889)  loss_giou: 0.1257 (0.1363)  loss_ce_0: 0.0373 (0.0507)  loss_bbox_0: 0.1131 (0.1235)  loss_giou_0: 0.1835 (0.1880)  loss_ce_1: 0.0264 (0.0309)  loss_bbox_1: 0.0988 (0.1012)  loss_giou_1: 0.1563 (0.1536)  loss_ce_2: 0.0119 (0.0195)  loss_bbox_2: 0.0930 (0.0982)  loss_giou_2: 0.1414 (0.1466)  loss_ce_3: 0.0105 (0.0178)  loss_bbox_3: 0.0930 (0.0930)  loss_giou_3: 0.1355 (0.1403)  loss_ce_4: 0.0089 (0.0181)  loss_bbox_4: 0.0894 (0.0889)  loss_giou_4: 0.1280 (0.1367)  loss_ce_unscaled: 0.0085 (0.0184)  class_error_unscaled: 0.0000 (2.7051)  loss_bbox_unscaled: 0.0179 (0.0178)  loss_giou_unscaled: 0.0629 (0.0681)  cardinality_error_unscaled: 0.0625 (0.0942)  loss_ce_0_unscaled: 0.0373 (0.0507)  loss_bbox_0_unscaled: 0.0226 (0.0247)  loss_giou_0_unscaled: 0.0918 (0.0940)  cardinality_error_0_unscaled: 0.7500 (0.9750)  loss_ce_1_unscaled: 0.0264 (0.0309)  loss_bbox_1_unscaled: 0.0198 (0.0202)  loss_giou_1_unscaled: 0.0781 (0.0768)  cardinality_error_1_unscaled: 0.3125 (0.4490)  loss_ce_2_unscaled: 0.0119 (0.0195)  loss_bbox_2_unscaled: 0.0186 (0.0196)  loss_giou_2_unscaled: 0.0707 (0.0733)  cardinality_error_2_unscaled: 0.1250 (0.1279)  loss_ce_3_unscaled: 0.0105 (0.0178)  loss_bbox_3_unscaled: 0.0186 (0.0186)  loss_giou_3_unscaled: 0.0677 (0.0702)  cardinality_error_3_unscaled: 0.1250 (0.0947)  loss_ce_4_unscaled: 0.0089 (0.0181)  loss_bbox_4_unscaled: 0.0179 (0.0178)  loss_giou_4_unscaled: 0.0640 (0.0684)  cardinality_error_4_unscaled: 0.0625 (0.0894)
# Test:  [ 0/33]  eta: 0:18:39  class_error: 4.17  loss: 1.9996 (1.9996)  loss_ce: 0.0499 (0.0499)  loss_bbox: 0.0985 (0.0985)  loss_giou: 0.1677 (0.1677)  loss_ce_0: 0.1141 (0.1141)  loss_bbox_0: 0.1073 (0.1073)  loss_giou_0: 0.1772 (0.1772)  loss_ce_1: 0.0683 (0.0683)  loss_bbox_1: 0.1050 (0.1050)  loss_giou_1: 0.1740 (0.1740)  loss_ce_2: 0.0517 (0.0517)  loss_bbox_2: 0.1006 (0.1006)  loss_giou_2: 0.1644 (0.1644)  loss_ce_3: 0.0529 (0.0529)  loss_bbox_3: 0.0983 (0.0983)  loss_giou_3: 0.1596 (0.1596)  loss_ce_4: 0.0518 (0.0518)  loss_bbox_4: 0.0969 (0.0969)  loss_giou_4: 0.1613 (0.1613)  loss_ce_unscaled: 0.0499 (0.0499)  class_error_unscaled: 4.1667 (4.1667)  loss_bbox_unscaled: 0.0197 (0.0197)  loss_giou_unscaled: 0.0838 (0.0838)  cardinality_error_unscaled: 0.3125 (0.3125)  loss_ce_0_unscaled: 0.1141 (0.1141)  loss_bbox_0_unscaled: 0.0215 (0.0215)  loss_giou_0_unscaled: 0.0886 (0.0886)  cardinality_error_0_unscaled: 1.0000 (1.0000)  loss_ce_1_unscaled: 0.0683 (0.0683)  loss_bbox_1_unscaled: 0.0210 (0.0210)  loss_giou_1_unscaled: 0.0870 (0.0870)  cardinality_error_1_unscaled: 0.6875 (0.6875)  loss_ce_2_unscaled: 0.0517 (0.0517)  loss_bbox_2_unscaled: 0.0201 (0.0201)  loss_giou_2_unscaled: 0.0822 (0.0822)  cardinality_error_2_unscaled: 0.2500 (0.2500)  loss_ce_3_unscaled: 0.0529 (0.0529)  loss_bbox_3_unscaled: 0.0197 (0.0197)  loss_giou_3_unscaled: 0.0798 (0.0798)  cardinality_error_3_unscaled: 0.2500 (0.2500)  loss_ce_4_unscaled: 0.0518 (0.0518)  loss_bbox_4_unscaled: 0.0194 (0.0194)  loss_giou_4_unscaled: 0.0806 (0.0806)  cardinality_error_4_unscaled: 0.3125 (0.3125)  time: 33.9317  data: 8.2961
# Test:  [10/33]  eta: 0:12:58  class_error: 6.25  loss: 1.3014 (1.4269)  loss_ce: 0.0050 (0.0162)  loss_bbox: 0.0855 (0.0881)  loss_giou: 0.1195 (0.1165)  loss_ce_0: 0.0351 (0.0441)  loss_bbox_0: 0.0975 (0.1041)  loss_giou_0: 0.1231 (0.1342)  loss_ce_1: 0.0161 (0.0245)  loss_bbox_1: 0.0970 (0.0986)  loss_giou_1: 0.1250 (0.1283)  loss_ce_2: 0.0063 (0.0200)  loss_bbox_2: 0.0914 (0.0911)  loss_giou_2: 0.1209 (0.1212)  loss_ce_3: 0.0060 (0.0143)  loss_bbox_3: 0.0867 (0.0898)  loss_giou_3: 0.1140 (0.1172)  loss_ce_4: 0.0053 (0.0166)  loss_bbox_4: 0.0861 (0.0872)  loss_giou_4: 0.1156 (0.1150)  loss_ce_unscaled: 0.0050 (0.0162)  class_error_unscaled: 0.0000 (2.3193)  loss_bbox_unscaled: 0.0171 (0.0176)  loss_giou_unscaled: 0.0597 (0.0583)  cardinality_error_unscaled: 0.0625 (0.0795)  loss_ce_0_unscaled: 0.0351 (0.0441)  loss_bbox_0_unscaled: 0.0195 (0.0208)  loss_giou_0_unscaled: 0.0615 (0.0671)  cardinality_error_0_unscaled: 0.5000 (0.5398)  loss_ce_1_unscaled: 0.0161 (0.0245)  loss_bbox_1_unscaled: 0.0194 (0.0197)  loss_giou_1_unscaled: 0.0625 (0.0641)  cardinality_error_1_unscaled: 0.3125 (0.3182)  loss_ce_2_unscaled: 0.0063 (0.0200)  loss_bbox_2_unscaled: 0.0183 (0.0182)  loss_giou_2_unscaled: 0.0605 (0.0606)  cardinality_error_2_unscaled: 0.0625 (0.0966)  loss_ce_3_unscaled: 0.0060 (0.0143)  loss_bbox_3_unscaled: 0.0173 (0.0180)  loss_giou_3_unscaled: 0.0570 (0.0586)  cardinality_error_3_unscaled: 0.0625 (0.0682)  loss_ce_4_unscaled: 0.0053 (0.0166)  loss_bbox_4_unscaled: 0.0172 (0.0174)  loss_giou_4_unscaled: 0.0578 (0.0575)  cardinality_error_4_unscaled: 0.0625 (0.0795)  time: 33.8362  data: 0.8861
# Test:  [20/33]  eta: 0:06:47  class_error: 5.26  loss: 1.2554 (1.4331)  loss_ce: 0.0116 (0.0185)  loss_bbox: 0.0813 (0.0844)  loss_giou: 0.1093 (0.1164)  loss_ce_0: 0.0341 (0.0465)  loss_bbox_0: 0.0973 (0.1026)  loss_giou_0: 0.1347 (0.1422)  loss_ce_1: 0.0209 (0.0271)  loss_bbox_1: 0.0914 (0.0944)  loss_giou_1: 0.1171 (0.1295)  loss_ce_2: 0.0128 (0.0216)  loss_bbox_2: 0.0844 (0.0897)  loss_giou_2: 0.1209 (0.1232)  loss_ce_3: 0.0078 (0.0172)  loss_bbox_3: 0.0803 (0.0863)  loss_giou_3: 0.1100 (0.1163)  loss_ce_4: 0.0116 (0.0186)  loss_bbox_4: 0.0802 (0.0838)  loss_giou_4: 0.1084 (0.1147)  loss_ce_unscaled: 0.0116 (0.0185)  class_error_unscaled: 0.0000 (3.0351)  loss_bbox_unscaled: 0.0163 (0.0169)  loss_giou_unscaled: 0.0547 (0.0582)  cardinality_error_unscaled: 0.0625 (0.0804)  loss_ce_0_unscaled: 0.0341 (0.0465)  loss_bbox_0_unscaled: 0.0195 (0.0205)  loss_giou_0_unscaled: 0.0673 (0.0711)  cardinality_error_0_unscaled: 0.5000 (0.5595)  loss_ce_1_unscaled: 0.0209 (0.0271)  loss_bbox_1_unscaled: 0.0183 (0.0189)  loss_giou_1_unscaled: 0.0585 (0.0648)  cardinality_error_1_unscaled: 0.1875 (0.2976)  loss_ce_2_unscaled: 0.0128 (0.0216)  loss_bbox_2_unscaled: 0.0169 (0.0179)  loss_giou_2_unscaled: 0.0605 (0.0616)  cardinality_error_2_unscaled: 0.0625 (0.0952)  loss_ce_3_unscaled: 0.0078 (0.0172)  loss_bbox_3_unscaled: 0.0161 (0.0173)  loss_giou_3_unscaled: 0.0550 (0.0582)  cardinality_error_3_unscaled: 0.0625 (0.0774)  loss_ce_4_unscaled: 0.0116 (0.0186)  loss_bbox_4_unscaled: 0.0160 (0.0168)  loss_giou_4_unscaled: 0.0542 (0.0573)  cardinality_error_4_unscaled: 0.0625 (0.0804)  time: 31.1880  data: 0.0782
# Test:  [30/33]  eta: 0:01:31  class_error: 0.00  loss: 1.3749 (1.4574)  loss_ce: 0.0073 (0.0173)  loss_bbox: 0.0763 (0.0803)  loss_giou: 0.1267 (0.1228)  loss_ce_0: 0.0352 (0.0442)  loss_bbox_0: 0.0973 (0.1006)  loss_giou_0: 0.1567 (0.1537)  loss_ce_1: 0.0209 (0.0272)  loss_bbox_1: 0.0824 (0.0907)  loss_giou_1: 0.1359 (0.1378)  loss_ce_2: 0.0103 (0.0203)  loss_bbox_2: 0.0792 (0.0866)  loss_giou_2: 0.1380 (0.1329)  loss_ce_3: 0.0083 (0.0167)  loss_bbox_3: 0.0789 (0.0828)  loss_giou_3: 0.1224 (0.1246)  loss_ce_4: 0.0076 (0.0174)  loss_bbox_4: 0.0728 (0.0796)  loss_giou_4: 0.1197 (0.1218)  loss_ce_unscaled: 0.0073 (0.0173)  class_error_unscaled: 0.0000 (2.4841)  loss_bbox_unscaled: 0.0153 (0.0161)  loss_giou_unscaled: 0.0633 (0.0614)  cardinality_error_unscaled: 0.0625 (0.0927)  loss_ce_0_unscaled: 0.0352 (0.0442)  loss_bbox_0_unscaled: 0.0195 (0.0201)  loss_giou_0_unscaled: 0.0784 (0.0768)  cardinality_error_0_unscaled: 0.6250 (0.5847)  loss_ce_1_unscaled: 0.0209 (0.0272)  loss_bbox_1_unscaled: 0.0165 (0.0181)  loss_giou_1_unscaled: 0.0679 (0.0689)  cardinality_error_1_unscaled: 0.2500 (0.2984)  loss_ce_2_unscaled: 0.0103 (0.0203)  loss_bbox_2_unscaled: 0.0158 (0.0173)  loss_giou_2_unscaled: 0.0690 (0.0664)  cardinality_error_2_unscaled: 0.0625 (0.1129)  loss_ce_3_unscaled: 0.0083 (0.0167)  loss_bbox_3_unscaled: 0.0158 (0.0166)  loss_giou_3_unscaled: 0.0612 (0.0623)  cardinality_error_3_unscaled: 0.0625 (0.0907)  loss_ce_4_unscaled: 0.0076 (0.0174)  loss_bbox_4_unscaled: 0.0146 (0.0159)  loss_giou_4_unscaled: 0.0599 (0.0609)  cardinality_error_4_unscaled: 0.0625 (0.0907)  time: 28.8809  data: 0.0117
# Test:  [32/33]  eta: 0:00:30  class_error: 0.00  loss: 1.4308 (1.4607)  loss_ce: 0.0067 (0.0164)  loss_bbox: 0.0763 (0.0804)  loss_giou: 0.1319 (0.1238)  loss_ce_0: 0.0373 (0.0444)  loss_bbox_0: 0.0976 (0.1006)  loss_giou_0: 0.1655 (0.1551)  loss_ce_1: 0.0156 (0.0260)  loss_bbox_1: 0.0833 (0.0909)  loss_giou_1: 0.1399 (0.1390)  loss_ce_2: 0.0072 (0.0194)  loss_bbox_2: 0.0816 (0.0869)  loss_giou_2: 0.1484 (0.1345)  loss_ce_3: 0.0057 (0.0159)  loss_bbox_3: 0.0761 (0.0828)  loss_giou_3: 0.1284 (0.1254)  loss_ce_4: 0.0061 (0.0166)  loss_bbox_4: 0.0714 (0.0797)  loss_giou_4: 0.1276 (0.1228)  loss_ce_unscaled: 0.0067 (0.0164)  class_error_unscaled: 0.0000 (2.3335)  loss_bbox_unscaled: 0.0153 (0.0161)  loss_giou_unscaled: 0.0660 (0.0619)  cardinality_error_unscaled: 0.0625 (0.0913)  loss_ce_0_unscaled: 0.0373 (0.0444)  loss_bbox_0_unscaled: 0.0195 (0.0201)  loss_giou_0_unscaled: 0.0828 (0.0776)  cardinality_error_0_unscaled: 0.6250 (0.5803)  loss_ce_1_unscaled: 0.0156 (0.0260)  loss_bbox_1_unscaled: 0.0167 (0.0182)  loss_giou_1_unscaled: 0.0699 (0.0695)  cardinality_error_1_unscaled: 0.2500 (0.2883)  loss_ce_2_unscaled: 0.0072 (0.0194)  loss_bbox_2_unscaled: 0.0163 (0.0174)  loss_giou_2_unscaled: 0.0742 (0.0673)  cardinality_error_2_unscaled: 0.0625 (0.1103)  loss_ce_3_unscaled: 0.0057 (0.0159)  loss_bbox_3_unscaled: 0.0152 (0.0166)  loss_giou_3_unscaled: 0.0642 (0.0627)  cardinality_error_3_unscaled: 0.0625 (0.0895)  loss_ce_4_unscaled: 0.0061 (0.0166)  loss_bbox_4_unscaled: 0.0143 (0.0159)  loss_giou_4_unscaled: 0.0638 (0.0614)  cardinality_error_4_unscaled: 0.0625 (0.0895)  time: 28.7045  data: 0.0115
# Test: Total time: 0:16:57 (30.8476 s / it)
# Averaged stats: class_error: 0.00  loss: 1.4308 (1.4607)  loss_ce: 0.0067 (0.0164)  loss_bbox: 0.0763 (0.0804)  loss_giou: 0.1319 (0.1238)  loss_ce_0: 0.0373 (0.0444)  loss_bbox_0: 0.0976 (0.1006)  loss_giou_0: 0.1655 (0.1551)  loss_ce_1: 0.0156 (0.0260)  loss_bbox_1: 0.0833 (0.0909)  loss_giou_1: 0.1399 (0.1390)  loss_ce_2: 0.0072 (0.0194)  loss_bbox_2: 0.0816 (0.0869)  loss_giou_2: 0.1484 (0.1345)  loss_ce_3: 0.0057 (0.0159)  loss_bbox_3: 0.0761 (0.0828)  loss_giou_3: 0.1284 (0.1254)  loss_ce_4: 0.0061 (0.0166)  loss_bbox_4: 0.0714 (0.0797)  loss_giou_4: 0.1276 (0.1228)  loss_ce_unscaled: 0.0067 (0.0164)  class_error_unscaled: 0.0000 (2.3335)  loss_bbox_unscaled: 0.0153 (0.0161)  loss_giou_unscaled: 0.0660 (0.0619)  cardinality_error_unscaled: 0.0625 (0.0913)  loss_ce_0_unscaled: 0.0373 (0.0444)  loss_bbox_0_unscaled: 0.0195 (0.0201)  loss_giou_0_unscaled: 0.0828 (0.0776)  cardinality_error_0_unscaled: 0.6250 (0.5803)  loss_ce_1_unscaled: 0.0156 (0.0260)  loss_bbox_1_unscaled: 0.0167 (0.0182)  loss_giou_1_unscaled: 0.0699 (0.0695)  cardinality_error_1_unscaled: 0.2500 (0.2883)  loss_ce_2_unscaled: 0.0072 (0.0194)  loss_bbox_2_unscaled: 0.0163 (0.0174)  loss_giou_2_unscaled: 0.0742 (0.0673)  cardinality_error_2_unscaled: 0.0625 (0.1103)  loss_ce_3_unscaled: 0.0057 (0.0159)  loss_bbox_3_unscaled: 0.0152 (0.0166)  loss_giou_3_unscaled: 0.0642 (0.0627)  cardinality_error_3_unscaled: 0.0625 (0.0895)  loss_ce_4_unscaled: 0.0061 (0.0166)  loss_bbox_4_unscaled: 0.0143 (0.0159)  loss_giou_4_unscaled: 0.0638 (0.0614)  cardinality_error_4_unscaled: 0.0625 (0.0895)
# Accumulating evaluation results...
# Traceback (most recent call last):
#   File "/Users/coralavital/Desktop/vscode/finetune-detr/detr/main.py", line 250, in <module>
#     main(args)
#   File "/Users/coralavital/Desktop/vscode/finetune-detr/detr/main.py", line 216, in main
#     test_stats, coco_evaluator = evaluate(
#   File "/Users/coralavital/Desktop/vscode/finetune-detr/venv/lib/python3.9/site-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/Users/coralavital/Desktop/vscode/finetune-detr/detr/engine.py", line 136, in evaluate
#     coco_evaluator.accumulate()
#   File "/Users/coralavital/Desktop/vscode/finetune-detr/detr/datasets/coco_eval.py", line 62, in accumulate
#     coco_eval.accumulate()
#   File "/Users/coralavital/Desktop/vscode/finetune-detr/venv/lib/python3.9/site-packages/pycocotools/cocoeval.py", line 378, in accumulate
#     tp_sum = np.cumsum(tps, axis=1).astype(dtype=np.float)
#   File "/Users/coralavital/Desktop/vscode/finetune-detr/venv/lib/python3.9/site-packages/numpy/__init__.py", line 305, in __getattr__
#     raise AttributeError(__former_attrs__[attr])
# AttributeError: module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# ## Check the results

# %% [markdown]
# ### Monitoring of training
#
# Reference: https://github.com/lessw2020/Thunder-Detr/blob/master/View_your_training_results.ipynb

# %%
from detr.util.plot_utils import plot_logs

from pathlib import Path

log_directory = [Path('outputs/36epoch/')]

# %% [markdown]
# As mentioned in the code of [`plot_logs`](https://github.com/facebookresearch/detr/blob/5e66b4cd15b2b182da347103dd16578d28b49d69/util/plot_utils.py#L13):
# -   solid lines are training results,
# -   dashed lines are validation results.

# %%
fields_of_interest = (
    'loss',
    'mAP',
    )

plot_logs(log_directory,
          fields_of_interest)

# %%
fields_of_interest = (
    'loss_ce',
    'loss_bbox',
    'loss_giou',
    )

plot_logs(log_directory,
          fields_of_interest)

# %%
fields_of_interest = (
    'class_error',
    'cardinality_error_unscaled',
    )

plot_logs(log_directory,
          fields_of_interest)

# %% [markdown]
# ### Load the fine-tuned model
#
# - How to replace the classification head: https://github.com/facebookresearch/detr/issues/9#issuecomment-636391562

# %%
model = torch.hub.load('facebookresearch/detr',
                       'detr_resnet50',
                       pretrained=False,
                       num_classes=num_classes)

checkpoint = torch.load('outputs/36epoch/checkpoint.pth',
                        map_location='cpu')

model.load_state_dict(checkpoint['model'],
                      strict=False)

print(model.eval())
# Out:
# Using cache found in /Users/coralavital/.cache/torch/hub/facebookresearch_detr_main
# DETR(
#   (transformer): Transformer(
#     (encoder): TransformerEncoder(
#       (layers): ModuleList(
#         (0-5): 6 x TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (decoder): TransformerDecoder(
#       (layers): ModuleList(
#         (0-5): 6 x TransformerDecoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (multihead_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm3): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#           (dropout3): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (class_embed): Linear(in_features=256, out_features=6, bias=True)
#   (bbox_embed): MLP(
#     (layers): ModuleList(
#       (0-1): 2 x Linear(in_features=256, out_features=256, bias=True)
#       (2): Linear(in_features=256, out_features=4, bias=True)
#     )
#   )
#   (query_embed): Embedding(100, 256)
#   (input_proj): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#   (backbone): Joiner(
#     (0): Backbone(
#       (body): IntermediateLayerGetter(
#         (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#         (bn1): FrozenBatchNorm2d()
#         (relu): ReLU(inplace=True)
#         (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         (layer1): Sequential(
#           (0): Bottleneck(
#             (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): FrozenBatchNorm2d()
#             )
#           )
#           (1): Bottleneck(
#             (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (2): Bottleneck(
#             (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (layer2): Sequential(
#           (0): Bottleneck(
#             (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (1): FrozenBatchNorm2d()
#             )
#           )
#           (1): Bottleneck(
#             (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (2): Bottleneck(
#             (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (3): Bottleneck(
#             (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (layer3): Sequential(
#           (0): Bottleneck(
#             (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (1): FrozenBatchNorm2d()
#             )
#           )
#           (1): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (2): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (3): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (4): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (5): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (layer4): Sequential(
#           (0): Bottleneck(
#             (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (1): FrozenBatchNorm2d()
#             )
#           )
#           (1): Bottleneck(
#             (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (2): Bottleneck(
#             (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (1): PositionEmbeddingSine()
#   )
# )

# %% [markdown]
# ### Boilerplate functions to display fine-tuned results

# %%
def plot_finetuned_results(pil_img, prob=None, boxes=None):
    plt.figure(figsize=(16,10))
    plt.imshow(pil_img)
    ax = plt.gca()
    colors = COLORS * 100
    if prob is not None and boxes is not None:
      for p, (xmin, ymin, xmax, ymax), c in zip(prob, boxes.tolist(), colors):
          ax.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                    fill=False, color=c, linewidth=3))
          cl = p.argmax()
          text = f'{finetuned_classes[cl]}: {p[cl]:0.2f}'
          ax.text(xmin, ymin, text, fontsize=15,
                  bbox=dict(facecolor='yellow', alpha=0.5))
    plt.axis('off')
    plt.show()

# %%
def run_worflow(my_image, my_model):
  # mean-std normalize the input image (batch-size: 1)
  img = transform(my_image).unsqueeze(0)

  # propagate through the model
  outputs = my_model(img)

  for threshold in [0.9, 0.7]:
    
    probas_to_keep, bboxes_scaled = filter_bboxes_from_outputs(outputs,
                                                              threshold=threshold)

    plot_finetuned_results(my_image,
                           probas_to_keep, 
                           bboxes_scaled)

# %% [markdown]
# ### With a training image

# %%
from PIL import Image
import os
import random 

path="custom/train2017/"
images = os.listdir(path)
image = random.choice(images)
im = Image.open(path + image)

run_worflow(im,
            model)

# %% [markdown]
# ### With a validation image

# %%
from PIL import Image
import os
import random 

path="custom/val2017/"
images = os.listdir(path)
image = random.choice(images)
im = Image.open(path + image)

run_worflow(im,
            model)

# %% [markdown]
# ## Save model.pt file

# %%
checkpoint = torch.load('outputs/36epoch/checkpoint.pth',
                        map_location='cpu')

model.load_state_dict(checkpoint['model'],
                      strict=False)

model.eval()

torch.save(model.state_dict(), 'outputs/36epoch/model.pt')

# %% [markdown]
# ## Load model.pt

# %%
state_dict = torch.load('outputs/36epoch/model.pt')
model = torch.hub.load('facebookresearch/detr',
                       'detr_resnet50',
                       pretrained=False,
                       num_classes=num_classes)
model.load_state_dict(state_dict)
model.eval()  # Set the model to evaluation mode
# Out:
# Using cache found in /Users/coralavital/.cache/torch/hub/facebookresearch_detr_main
# DETR(
#   (transformer): Transformer(
#     (encoder): TransformerEncoder(
#       (layers): ModuleList(
#         (0-5): 6 x TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (decoder): TransformerDecoder(
#       (layers): ModuleList(
#         (0-5): 6 x TransformerDecoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (multihead_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#           )
#           (linear1): Linear(in_features=256, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=256, bias=True)
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (norm3): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#           (dropout3): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (class_embed): Linear(in_features=256, out_features=6, bias=True)
#   (bbox_embed): MLP(
#     (layers): ModuleList(
#       (0-1): 2 x Linear(in_features=256, out_features=256, bias=True)
#       (2): Linear(in_features=256, out_features=4, bias=True)
#     )
#   )
#   (query_embed): Embedding(100, 256)
#   (input_proj): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#   (backbone): Joiner(
#     (0): Backbone(
#       (body): IntermediateLayerGetter(
#         (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#         (bn1): FrozenBatchNorm2d()
#         (relu): ReLU(inplace=True)
#         (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         (layer1): Sequential(
#           (0): Bottleneck(
#             (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): FrozenBatchNorm2d()
#             )
#           )
#           (1): Bottleneck(
#             (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (2): Bottleneck(
#             (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (layer2): Sequential(
#           (0): Bottleneck(
#             (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (1): FrozenBatchNorm2d()
#             )
#           )
#           (1): Bottleneck(
#             (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (2): Bottleneck(
#             (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (3): Bottleneck(
#             (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (layer3): Sequential(
#           (0): Bottleneck(
#             (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (1): FrozenBatchNorm2d()
#             )
#           )
#           (1): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (2): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (3): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (4): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (5): Bottleneck(
#             (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (layer4): Sequential(
#           (0): Bottleneck(
#             (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (1): FrozenBatchNorm2d()
#             )
#           )
#           (1): Bottleneck(
#             (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#           (2): Bottleneck(
#             (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): FrozenBatchNorm2d()
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): FrozenBatchNorm2d()
#             (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn3): FrozenBatchNorm2d()
#             (relu): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (1): PositionEmbeddingSine()
#   )
# )
